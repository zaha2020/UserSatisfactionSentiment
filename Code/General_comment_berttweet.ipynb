# %%
# !pip install datasets transformers evaluate
# Out:
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 12.5 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 109.9 MB/s eta 0:00:00
# Collecting evaluate
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 37.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 65.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.1 MB/s eta 0:00:00
# Collecting responses<0.19 (from evaluate)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: safetensors, dill, responses, multiprocess, huggingface-hub, tokenizers, transformers, datasets, evaluate
# Successfully installed datasets-2.14.5 dill-0.3.7 evaluate-0.4.1 huggingface-hub-0.17.3 multiprocess-0.70.15 responses-0.18.0 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
import numpy  as np
import pandas as pd
from datasets import Dataset, DatasetDict, load_metric
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer
import tensorflow as tf
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import losses
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
from transformers import DataCollatorWithPadding
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn import metrics
import matplotlib.pyplot as plt
import numpy

# %%
# read test and trian data and use Dataset library
data = DatasetDict()
df_train = pd.read_csv("/content/train_related.csv", usecols = ['Record_text', 'InRelationship','General_comment_binary','General_comment','Specific_comment_binary','Specific_comment','Comment','Relevance'], on_bad_lines='skip')
df_train = df_train.rename(columns={'General_comment': 'label'})
data['train'] = Dataset.from_pandas(df_train)

df_test = pd.read_csv("/content/test_related.csv", usecols = ['Record_text', 'InRelationship','General_comment_binary','General_comment','Specific_comment_binary','Specific_comment','Comment','Relevance'], on_bad_lines='skip')
df_test = df_test.rename(columns={'General_comment': 'label'})
df_test_unfreeze=df_test.copy()
df_test_unfreeze_11=df_test.copy()
df_test_freeze=df_test.copy()

data['test'] = Dataset.from_pandas(df_test)

# %%
from transformers import BertForMaskedLM, BertTokenizer, pipeline
tokenizer = BertTokenizer.from_pretrained('arm-on/BERTweet-FA')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/274 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/297k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
#tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-base-parsbert-uncased")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/1.22M [00:00<?, ?B/s]

# %%
# Tokenization function
def tokenize(batch):
    return tokenizer(batch["Record_text"], padding=True, truncation=True, max_length = 50)
# Tokenize entire dataset
tokenized_dataset = data.map(tokenize, batched=True, batch_size=None)
# Out:
# Map:   0%|          | 0/5540 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1225 [00:00<?, ? examples/s]

# %%
#Select mode of model
def freeze(model,mode):
    if mode=='unfreeze':
       for layer in model.get_layer('bert').encoder.layer:
            print(f"{layer.name}: {layer.trainable}")
    elif mode=='unfreeze_11':
       for layer in model.layers:
           layer.trainable = False
       model.get_layer('bert').encoder.layer[11].trainable=True  #11
       model.layers[-1].trainable = True   #12
       for layer in model.get_layer('bert').encoder.layer:
           print(f"{layer.name}: {layer.trainable}")
    else:
       for layer in model.layers:
           layer.trainable = False
       model.layers[-1].trainable = True  #12
       for layer in model.get_layer('bert').encoder.layer:
           print(f"{layer.name}: {layer.trainable}")
    return model

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, return_tensors="tf")

# %%
# Create tf datasets
BAtch_Size = 128
tf_train_dataset = tokenized_dataset["train"].to_tf_dataset(
    columns= ['input_ids', 'token_type_ids', 'attention_mask', 'label'],
    label_cols=["label"],
    shuffle=True,
    batch_size=BAtch_Size,
    collate_fn=data_collator
)
tf_valid_dataset = tokenized_dataset["test"].to_tf_dataset(
    columns=['input_ids', 'token_type_ids', 'attention_mask', 'label'],
    label_cols=["label"],
    shuffle=False,
    batch_size=BAtch_Size,
    collate_fn=data_collator
)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/arrow_dataset.py:400: FutureWarning: The output of `to_tf_dataset` will change when a passing single element list for `labels` or `columns` in the next datasets version. To return a tuple structure rather than dict, pass a single string.
# Old behaviour: columns=['a'], labels=['labels'] -> (tf.Tensor, tf.Tensor)
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
# New behaviour: columns=['a'],labels=['labels'] -> ({'a': tf.Tensor}, {'labels': tf.Tensor})
#              : columns='a', labels='labels' -> (tf.Tensor, tf.Tensor)
#   warnings.warn(

# %%
def compile(model):
  # Compile the model
  model.compile(
    optimizer=optimizers.Adam(learning_rate=9e-5),
    loss=model.hf_compute_loss,
    metrics=metrics.SparseCategoricalAccuracy()
)
  return model

# %%
# Training_function
def training(model,Epoch):
    EPOCHS = Epoch
    checkpoint_filepath = '/content/"training\cp.ckpt" '
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True)

    history = model.fit(tf_train_dataset,
              validation_data=tf_valid_dataset,
              epochs=EPOCHS)
             # callbacks=[model_checkpoint_callback])

# %%
#Mode
mode=['unfreeze','unfreeze_11','freeze']

# %% [markdown]
# ## Mode: Un-freeze

# %%
from transformers import BertTokenizer, TFBertForSequenceClassification

# %%
num_labels=3
model_ = TFBertForSequenceClassification.from_pretrained('arm-on/BERTweet-FA',num_labels=num_labels,
                                                            id2label={0: 'positive', 1: 'negative',2:'neutral'}, from_pt=True)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias', 'classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_=freeze(model_,mode[0])
# Out:
# layer_._0: True
# layer_._1: True
# layer_._2: True
# layer_._3: True
# layer_._4: True
# layer_._5: True
# layer_._6: True
# layer_._7: True
# layer_._8: True
# layer_._9: True
# layer_._10: True
# layer_._11: True

# %%
#Compile
model_=compile(model_)

# %% [markdown]
# ---------------------------------------------------------------------------------------------Training-------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### 3,more than 3 epoch --------->overfitt
# #### Epoch = 3

# %%
training(model_,2)
# Out:
# Epoch 1/2
# 44/44 [==============================] - 104s 1s/step - loss: 0.9571 - sparse_categorical_accuracy: 0.5455 - val_loss: 0.8837 - val_sparse_categorical_accuracy: 0.6082
# Epoch 2/2
# 44/44 [==============================] - 54s 1s/step - loss: 0.7194 - sparse_categorical_accuracy: 0.6946 - val_loss: 0.8823 - val_sparse_categorical_accuracy: 0.6131

# %%
training(model_,3)
# Out:
# Epoch 1/3
# 44/44 [==============================] - 108s 1s/step - loss: 1.0076 - sparse_categorical_accuracy: 0.5002 - val_loss: 0.9233 - val_sparse_categorical_accuracy: 0.5624
# Epoch 2/3
# 44/44 [==============================] - 54s 1s/step - loss: 0.7745 - sparse_categorical_accuracy: 0.6556 - val_loss: 0.9047 - val_sparse_categorical_accuracy: 0.6155
# Epoch 3/3
# 44/44 [==============================] - 55s 1s/step - loss: 0.4780 - sparse_categorical_accuracy: 0.8143 - val_loss: 1.0433 - val_sparse_categorical_accuracy: 0.5984

# %%
training(model_,3)
# Out:
# Epoch 1/3
# 44/44 [==============================] - 108s 1s/step - loss: 0.9373 - sparse_categorical_accuracy: 0.5502 - val_loss: 0.8889 - val_sparse_categorical_accuracy: 0.6008
# Epoch 2/3
# 44/44 [==============================] - 56s 1s/step - loss: 0.6587 - sparse_categorical_accuracy: 0.7265 - val_loss: 0.9641 - val_sparse_categorical_accuracy: 0.5902
# Epoch 3/3
# 44/44 [==============================] - 56s 1s/step - loss: 0.3512 - sparse_categorical_accuracy: 0.8709 - val_loss: 1.2169 - val_sparse_categorical_accuracy: 0.6065

# %%
#training(model_,3)
# Out:
# Epoch 1/3
# 34/34 [==============================] - 93s 1s/step - loss: 1.0218 - sparse_categorical_accuracy: 0.4943 - val_loss: 0.9500 - val_sparse_categorical_accuracy: 0.5292
# Epoch 2/3
# 34/34 [==============================] - 40s 1s/step - loss: 0.8532 - sparse_categorical_accuracy: 0.6129 - val_loss: 0.9202 - val_sparse_categorical_accuracy: 0.5610
# Epoch 3/3
# 34/34 [==============================] - 43s 1s/step - loss: 0.5468 - sparse_categorical_accuracy: 0.7863 - val_loss: 1.0522 - val_sparse_categorical_accuracy: 0.5798

# %% [markdown]
# #### Epoch=10

# %%
#training(model_,10)
# Out:
# Epoch 1/10
# 34/34 [==============================] - 98s 1s/step - loss: 1.0321 - sparse_categorical_accuracy: 0.4796 - val_loss: 0.9321 - val_sparse_categorical_accuracy: 0.5748
# Epoch 2/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.8411 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.9603 - val_sparse_categorical_accuracy: 0.5550
# Epoch 3/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.5959 - sparse_categorical_accuracy: 0.7606 - val_loss: 1.0427 - val_sparse_categorical_accuracy: 0.5956
# Epoch 4/10
# 34/34 [==============================] - 45s 1s/step - loss: 0.3601 - sparse_categorical_accuracy: 0.8645 - val_loss: 1.1764 - val_sparse_categorical_accuracy: 0.5728
# Epoch 5/10
# 34/34 [==============================] - 44s 1s/step - loss: 0.1943 - sparse_categorical_accuracy: 0.9325 - val_loss: 1.4370 - val_sparse_categorical_accuracy: 0.5510
# Epoch 6/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.1250 - sparse_categorical_accuracy: 0.9617 - val_loss: 1.4333 - val_sparse_categorical_accuracy: 0.5580
# Epoch 7/10
# 34/34 [==============================] - 45s 1s/step - loss: 0.1014 - sparse_categorical_accuracy: 0.9664 - val_loss: 1.7937 - val_sparse_categorical_accuracy: 0.5768
# Epoch 8/10
# 34/34 [==============================] - 44s 1s/step - loss: 0.0691 - sparse_categorical_accuracy: 0.9792 - val_loss: 1.8383 - val_sparse_categorical_accuracy: 0.5649
# Epoch 9/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.0577 - sparse_categorical_accuracy: 0.9790 - val_loss: 2.1821 - val_sparse_categorical_accuracy: 0.5510
# Epoch 10/10
# 34/34 [==============================] - 42s 1s/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9822 - val_loss: 2.1835 - val_sparse_categorical_accuracy: 0.5352

# %% [markdown]
# ---------------------------------------------------------------------------------------------Evaluate_model-------------------------------------------------------------------------------------------------------------

# %%
def pred_label(text):
    inputs = tokenizer(text, return_tensors="tf")
    logits =  model_(inputs).logits
    #logits =  model_unfreeze_11(inputs).logits
    #logits =  model_freeze(inputs).logits
      # print(logits)
    predict = int(tf.math.argmax(logits, axis=-1)[0])
      # print(predict)
    return predict
def Evaluate_models(df_test,model,label,mode):
    print(f":::::::::::::::Performance of ParsBERT'{mode}' on '{label}' Label:::::::::::::::::::")
    df_test["pred_label"]= df_test["Record_text"].apply(lambda x:pred_label(x))
    Real_label = df_test["label"].values
    predictions = df_test["pred_label"].values
    accuracy = accuracy_score(Real_label, predictions)
    print(classification_report(Real_label, predictions, labels=[0, 1,2], zero_division=0))
        #accuracy = accuracy_score(y_test, preds[i])
    print(f'''Accuracy: {round(accuracy_score(Real_label, predictions, normalize=True),6)}
    \nPrecision:{round(precision_score(Real_label, predictions, average='macro'),6)}
    \nRecall: {round(recall_score(Real_label, predictions, average='macro'),6)}
    \nF1 score: {round(f1_score(Real_label, predictions, average='macro'),6)}''')
    print('\n')
    print('\n')
    print('\n')
    print('-----------------------------------------------------------------------------------------------------------')
    print('-----------------------------------------------------------------------------------------------------------')
    # confusion_matrix = metrics.confusion_matrix(Real_label, predictions)
    # cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1,2])
    # cm_display.plot()
    # plt.show()
    return df_test

# %%
Evaluate_models(df_test_unfreeze,model_,'General_comment',mode[0])
# Out:
# :::::::::::::::Performance of ParsBERT'unfreeze' on 'General_comment' Label:::::::::::::::::::
#               precision    recall  f1-score   support
#
#            0       0.65      0.42      0.51       269
#            1       0.66      0.77      0.71       575
#            2       0.53      0.54      0.53       381
#
#     accuracy                           0.62      1225
#    macro avg       0.61      0.57      0.59      1225
# weighted avg       0.62      0.62      0.61      1225
#
# Accuracy: 0.618776
#
# Precision:0.613292
#
# Recall: 0.574814
#
# F1 score: 0.585042
#
#
#
#
#
#
# -----------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------
#                                             Record_text  InRelationship  \
# 0     حالا در مورد زید یه خاکی بریز شوهر شد دوبار خا...              -1
# 1     : دوست پسر من باید مثل خودم کاسب باشه یعنی چی ...               1
# 2     : ولی نمیشه خانوم ها  تا شوهر کنن چهار به یک چ...              -1
# 3     من یکی از فانتزی هام اینکه اگه ازدواج کردم همس...               0
# 4     یه بحران دیگه داریم که به نظر بحران اصلی اونه:...               0
# ...                                                 ...             ...
# 1220  از اونجایی که همه چیز دو طرفست، وقتی راضی نیست...               1
# 1221  خفه شو بابا برو زنتو جمع کن از دست فرانسوی ها ...              -1
# 1222  خیانت ربطی به زیبایی پارتنر طرف نداره بلکه به ...              -1
# 1223  به زنم این دریافتم را گفتم. اون هم خوب که درمو...               1
# 1224  مرده رفته دادگاه گفته که نمیخوام زنم شهر دیگه ...              -1
#
#       General_comment_binary  label  Specific_comment_binary  \
# 0                          1      1                      0.0
# 1                          1      1                      1.0
# 2                          1      0                      0.0
# 3                          1      0                      0.0
# 4                          1      1                      0.0
# ...                      ...    ...                      ...
# 1220                       1      2                      1.0
# 1221                       1      1                      0.0
# 1222                       1      1                      0.0
# 1223                       1      2                      1.0
# 1224                       1      1                      0.0
#
#       Specific_comment                                            Comment  \
# 0                    3     احتمالا زید یه جیزی بوده که نوشته یه خاکی بریز
# 1                    1  دوست پسرش بهش پیام داده بریم بیرون اما این خوش...
# 2                    3  اینکه خانما الان یدونه شوهر میتونن داشته باشن،...
# 3                    3  این تبارها از نظر این شخص گزینه خوبی برای ازدو...
# 4                    3                                حرف ازدواج اصلا نزن
# ...                ...                                                ...
# 1220                 2                                              کامنت
# 1221                 3                                              کامنت
# 1222                 3                                              کامنت
# 1223                 2                                              کامنت
# 1224                 3                                              کامنت
#
#       Relevance  pred_label
# 0             1           2
# 1             1           1
# 2             1           1
# 3             1           2
# 4             1           1
# ...         ...         ...
# 1220          1           1
# 1221          1           1
# 1222          1           1
# 1223          1           2
# 1224          1           1
#
# [1225 rows x 9 columns]

# %%
df_test_unfreeze_positive_general= df_test_unfreeze[(df_test_unfreeze['label'] == 0) & (df_test_unfreeze['pred_label'] == 0)]
df_test_unfreeze_negative_general = df_test_unfreeze[(df_test_unfreeze['label'] == 1) & (df_test_unfreeze['pred_label'] == 1)]
df_test_unfreeze_neutral_general = df_test_unfreeze[(df_test_unfreeze['label'] == 2) & (df_test_unfreeze['pred_label'] == 2)]

# %%
df_test_unfreeze_positive_general.to_csv('/content/df_test_unfreeze_positive_general.csv')
df_test_unfreeze_negative_general.to_csv('/content/df_test_unfreeze_negative_general.csv')
df_test_unfreeze_neutral_general.to_csv('/content/df_test_unfreeze_neutral_general.csv')

# %%
df_test_unfreeze.to_csv('/content/df_test_unfreeze_general.csv')

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Mode: Freeze except layer 11

# %%
num_labels=3
model_unfreeze_11 = TFAutoModelForSequenceClassification.from_pretrained("HooshvareLab/bert-base-parsbert-uncased",
                                                             num_labels=num_labels,
                                                            id2label={0: 'positive', 1: 'negative',2:'neutral'})
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at HooshvareLab/bert-base-parsbert-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_unfreeze_11=freeze(model_unfreeze_11,mode[1])
# Out:
# layer_._0: False
# layer_._1: False
# layer_._2: False
# layer_._3: False
# layer_._4: False
# layer_._5: False
# layer_._6: False
# layer_._7: False
# layer_._8: False
# layer_._9: False
# layer_._10: False
# layer_._11: True

# %%
#Compile
model_unfreeze_11=compile(model_unfreeze_11)

# %% [markdown]
# ---------------------------------------------------------------------------------------------Training-------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Epoch =50

# %%
training(model_unfreeze_11,50)
# Out:
# Epoch 1/50
# 34/34 [==============================] - 36s 628ms/step - loss: 1.0716 - sparse_categorical_accuracy: 0.4223 - val_loss: 1.0433 - val_sparse_categorical_accuracy: 0.4777
# Epoch 2/50
# %%
Evaluate_models(df_test_unfreeze_11,model_unfreeze_11,'General_comment',mode[1])
# Out:
# :::::::::::::::Performance of ParsBERT'unfreeze_11' on 'General_comment' Label:::::::::::::::::::
#               precision    recall  f1-score   support
#
#            0       0.51      0.19      0.28       223
#            1       0.57      0.85      0.68       480
#            2       0.48      0.33      0.39       306
#
#     accuracy                           0.55      1009
#    macro avg       0.52      0.46      0.45      1009
# weighted avg       0.53      0.55      0.50      1009
#
# Accuracy: 0.545094
#
# Precision:0.519248
#
# Recall: 0.456241
#
# F1 score: 0.450243
#
#
#
#
#
#
# -----------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------
#                                             Record_text  InRelationship  \
# 0                     زید خاکی بریز شوهر دوبار خاک بریز              -1
# 1     دوست پسر کاسب ساعت   پیام میدین اوج بازاره دیوونه               1
# 2     عزیزی اندازه جان ادم نهار امد خونمون حسرت برطر...               1
# 3     نتونستم منظورمو برسونم خانمها نیاز بدونن مرد ح...              -1
# 4               شوهر اسمش استاد حسین علیزاده کیهان کلهر               0
# ...                                                 ...             ...
# 1004  جهانی بوسه یادی معصومه خاکیار بوسه سینمای ایرا...              -1
# 1005  کارمند حسو وقتیم کارمند حس زنیو شوهر معتاد خان...              -1
# 1006  اقا روابطتون دهنتونو بازکنید راجب هرچی ناراحتت...               1
# 1007  توییتر لینکداین اینه دفه   دوست دخترم دانشگاه ...               0
# 1008  تابستون سرکار تفریح گردش لباس مانتو شال نمیچسب...               1
#
#       General_comment_binary  label  Specific_comment_binary  \
# 0                          1      1                        0
# 1                          1      1                        1
# 2                          1      0                        1
# 3                          1      0                        0
# 4                          1      0                        0
# ...                      ...    ...                      ...
# 1004                       1      1                        0
# 1005                       1      1                        0
# 1006                       1      0                        1
# 1007                       1      0                        1
# 1008                       1      1                        1
#
#       Specific_comment                                            Comment  \
# 0                    3     احتمالا زید یه جیزی بوده که نوشته یه خاکی بریز
# 1                    1  دوست پسرش بهش پیام داده بریم بیرون اما این خوش...
# 2                    0                                     خیلی زحمت کشید
# 3                    3                                       مراقبت از هم
# 4                    3                                  این دو ادم الگوست
# ...                ...                                                ...
# 1004                 3                                                 بد
# 1005                 3                                                 بد
# 1006                 0                                            خوشایند
# 1007                 0                                                خوب
# 1008                 1                                                 بد
#
#       Relevance  pred_label
# 0             1           1
# 1             1           1
# 2             1           0
# 3             1           1
# 4             1           2
# ...         ...         ...
# 1004          1           0
# 1005          1           1
# 1006          1           1
# 1007          1           2
# 1008          1           1
#
# [1009 rows x 9 columns]

# %% [markdown]
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Mode: Freeze

# %%
num_labels=3
model_freeze = TFAutoModelForSequenceClassification.from_pretrained("HooshvareLab/bert-base-parsbert-uncased",
                                                             num_labels=num_labels,
                                                            id2label={0: 'positive', 1: 'negative',2:'neutral'})
# Out:
# All model checkpoint layers were used when initializing TFBertForSequenceClassification.
#
# Some layers of TFBertForSequenceClassification were not initialized from the model checkpoint at HooshvareLab/bert-base-parsbert-uncased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_freeze=freeze(model_freeze,mode[2])
# Out:
# layer_._0: False
# layer_._1: False
# layer_._2: False
# layer_._3: False
# layer_._4: False
# layer_._5: False
# layer_._6: False
# layer_._7: False
# layer_._8: False
# layer_._9: False
# layer_._10: False
# layer_._11: False

# %%
#Compile
model_freeze=compile(model_freeze)

# %% [markdown]
# ---------------------------------------------------------------------------------------------Training-------------------------------------------------------------------------------------------------------------

# %%
training(model_freeze,50)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 43s 609ms/step - loss: 1.0620 - sparse_categorical_accuracy: 0.4502 - val_loss: 1.0416 - val_sparse_categorical_accuracy: 0.4710
# Epoch 2/50
# 44/44 [==============================] - 23s 525ms/step - loss: 1.0366 - sparse_categorical_accuracy: 0.4773 - val_loss: 1.0270 - val_sparse_categorical_accuracy: 0.4792
# Epoch 3/50
# 44/44 [==============================] - 23s 520ms/step - loss: 1.0237 - sparse_categorical_accuracy: 0.4832 - val_loss: 1.0166 - val_sparse_categorical_accuracy: 0.4824
# Epoch 4/50
# 44/44 [==============================] - 25s 567ms/step - loss: 1.0149 - sparse_categorical_accuracy: 0.4886 - val_loss: 1.0093 - val_sparse_categorical_accuracy: 0.4816
# Epoch 5/50
# 44/44 [==============================] - 24s 543ms/step - loss: 1.0061 - sparse_categorical_accuracy: 0.4968 - val_loss: 1.0001 - val_sparse_categorical_accuracy: 0.5020
# Epoch 6/50
# 44/44 [==============================] - 25s 561ms/step - loss: 0.9994 - sparse_categorical_accuracy: 0.5007 - val_loss: 0.9943 - val_sparse_categorical_accuracy: 0.5004
# Epoch 7/50
# 44/44 [==============================] - 23s 523ms/step - loss: 0.9929 - sparse_categorical_accuracy: 0.5123 - val_loss: 0.9886 - val_sparse_categorical_accuracy: 0.5012
# Epoch 8/50
# 44/44 [==============================] - 23s 519ms/step - loss: 0.9890 - sparse_categorical_accuracy: 0.5065 - val_loss: 0.9830 - val_sparse_categorical_accuracy: 0.5135
# Epoch 9/50
# 44/44 [==============================] - 24s 548ms/step - loss: 0.9831 - sparse_categorical_accuracy: 0.5202 - val_loss: 0.9778 - val_sparse_categorical_accuracy: 0.5167
# Epoch 10/50
# 44/44 [==============================] - 24s 551ms/step - loss: 0.9786 - sparse_categorical_accuracy: 0.5190 - val_loss: 0.9743 - val_sparse_categorical_accuracy: 0.5159
# Epoch 11/50
# 44/44 [==============================] - 23s 527ms/step - loss: 0.9726 - sparse_categorical_accuracy: 0.5361 - val_loss: 0.9708 - val_sparse_categorical_accuracy: 0.5159
# Epoch 12/50
# 44/44 [==============================] - 23s 519ms/step - loss: 0.9708 - sparse_categorical_accuracy: 0.5202 - val_loss: 0.9670 - val_sparse_categorical_accuracy: 0.5265
# Epoch 13/50
# 44/44 [==============================] - 23s 523ms/step - loss: 0.9648 - sparse_categorical_accuracy: 0.5319 - val_loss: 0.9640 - val_sparse_categorical_accuracy: 0.5265
# Epoch 14/50
# 44/44 [==============================] - 23s 522ms/step - loss: 0.9643 - sparse_categorical_accuracy: 0.5300 - val_loss: 0.9601 - val_sparse_categorical_accuracy: 0.5388
# Epoch 15/50
# 44/44 [==============================] - 23s 524ms/step - loss: 0.9599 - sparse_categorical_accuracy: 0.5356 - val_loss: 0.9576 - val_sparse_categorical_accuracy: 0.5322
# Epoch 16/50
# 44/44 [==============================] - 24s 538ms/step - loss: 0.9604 - sparse_categorical_accuracy: 0.5343 - val_loss: 0.9556 - val_sparse_categorical_accuracy: 0.5371
# Epoch 17/50
# 44/44 [==============================] - 23s 522ms/step - loss: 0.9571 - sparse_categorical_accuracy: 0.5399 - val_loss: 0.9537 - val_sparse_categorical_accuracy: 0.5412
# Epoch 18/50
# 44/44 [==============================] - 24s 543ms/step - loss: 0.9538 - sparse_categorical_accuracy: 0.5493 - val_loss: 0.9508 - val_sparse_categorical_accuracy: 0.5396
# Epoch 19/50
# 44/44 [==============================] - 23s 522ms/step - loss: 0.9561 - sparse_categorical_accuracy: 0.5377 - val_loss: 0.9499 - val_sparse_categorical_accuracy: 0.5453
# Epoch 20/50
# 44/44 [==============================] - 24s 552ms/step - loss: 0.9460 - sparse_categorical_accuracy: 0.5424 - val_loss: 0.9482 - val_sparse_categorical_accuracy: 0.5429
# Epoch 21/50
# 44/44 [==============================] - 23s 523ms/step - loss: 0.9465 - sparse_categorical_accuracy: 0.5428 - val_loss: 0.9452 - val_sparse_categorical_accuracy: 0.5527
# Epoch 22/50
# 44/44 [==============================] - 23s 520ms/step - loss: 0.9450 - sparse_categorical_accuracy: 0.5460 - val_loss: 0.9434 - val_sparse_categorical_accuracy: 0.5535
# Epoch 23/50
# 44/44 [==============================] - 23s 524ms/step - loss: 0.9441 - sparse_categorical_accuracy: 0.5491 - val_loss: 0.9420 - val_sparse_categorical_accuracy: 0.5584
# Epoch 24/50
# 44/44 [==============================] - 23s 527ms/step - loss: 0.9415 - sparse_categorical_accuracy: 0.5482 - val_loss: 0.9413 - val_sparse_categorical_accuracy: 0.5543
# Epoch 25/50
# 44/44 [==============================] - 24s 539ms/step - loss: 0.9390 - sparse_categorical_accuracy: 0.5509 - val_loss: 0.9399 - val_sparse_categorical_accuracy: 0.5543
# Epoch 26/50
# 44/44 [==============================] - 23s 518ms/step - loss: 0.9399 - sparse_categorical_accuracy: 0.5509 - val_loss: 0.9388 - val_sparse_categorical_accuracy: 0.5624
# Epoch 27/50
# 44/44 [==============================] - 23s 519ms/step - loss: 0.9378 - sparse_categorical_accuracy: 0.5540 - val_loss: 0.9368 - val_sparse_categorical_accuracy: 0.5657
# Epoch 28/50
# 44/44 [==============================] - 24s 548ms/step - loss: 0.9346 - sparse_categorical_accuracy: 0.5558 - val_loss: 0.9368 - val_sparse_categorical_accuracy: 0.5584
# Epoch 29/50
# 44/44 [==============================] - 23s 524ms/step - loss: 0.9336 - sparse_categorical_accuracy: 0.5551 - val_loss: 0.9350 - val_sparse_categorical_accuracy: 0.5624
# Epoch 30/50
# 44/44 [==============================] - 23s 522ms/step - loss: 0.9321 - sparse_categorical_accuracy: 0.5547 - val_loss: 0.9339 - val_sparse_categorical_accuracy: 0.5690
# Epoch 31/50
# 44/44 [==============================] - 24s 546ms/step - loss: 0.9314 - sparse_categorical_accuracy: 0.5617 - val_loss: 0.9331 - val_sparse_categorical_accuracy: 0.5690
# Epoch 32/50
# 44/44 [==============================] - 23s 522ms/step - loss: 0.9345 - sparse_categorical_accuracy: 0.5522 - val_loss: 0.9323 - val_sparse_categorical_accuracy: 0.5690
# Epoch 33/50
# 44/44 [==============================] - 23s 525ms/step - loss: 0.9271 - sparse_categorical_accuracy: 0.5668 - val_loss: 0.9320 - val_sparse_categorical_accuracy: 0.5665
# Epoch 34/50
# 44/44 [==============================] - 23s 525ms/step - loss: 0.9291 - sparse_categorical_accuracy: 0.5614 - val_loss: 0.9309 - val_sparse_categorical_accuracy: 0.5665
# Epoch 35/50
# 44/44 [==============================] - 23s 523ms/step - loss: 0.9316 - sparse_categorical_accuracy: 0.5581 - val_loss: 0.9295 - val_sparse_categorical_accuracy: 0.5633
# Epoch 36/50
# 44/44 [==============================] - 23s 526ms/step - loss: 0.9281 - sparse_categorical_accuracy: 0.5610 - val_loss: 0.9310 - val_sparse_categorical_accuracy: 0.5567
# Epoch 37/50
# 44/44 [==============================] - 23s 531ms/step - loss: 0.9273 - sparse_categorical_accuracy: 0.5567 - val_loss: 0.9289 - val_sparse_categorical_accuracy: 0.5624
# Epoch 38/50
# 44/44 [==============================] - 24s 548ms/step - loss: 0.9255 - sparse_categorical_accuracy: 0.5652 - val_loss: 0.9292 - val_sparse_categorical_accuracy: 0.5608
# Epoch 39/50
# 44/44 [==============================] - 23s 533ms/step - loss: 0.9253 - sparse_categorical_accuracy: 0.5612 - val_loss: 0.9298 - val_sparse_categorical_accuracy: 0.5600
# Epoch 40/50
# 44/44 [==============================] - 23s 521ms/step - loss: 0.9259 - sparse_categorical_accuracy: 0.5581 - val_loss: 0.9285 - val_sparse_categorical_accuracy: 0.5567
# Epoch 41/50
# 44/44 [==============================] - 24s 545ms/step - loss: 0.9224 - sparse_categorical_accuracy: 0.5664 - val_loss: 0.9260 - val_sparse_categorical_accuracy: 0.5665
# Epoch 42/50
# 44/44 [==============================] - 24s 550ms/step - loss: 0.9255 - sparse_categorical_accuracy: 0.5616 - val_loss: 0.9256 - val_sparse_categorical_accuracy: 0.5673
# Epoch 43/50
# 44/44 [==============================] - 23s 532ms/step - loss: 0.9207 - sparse_categorical_accuracy: 0.5664 - val_loss: 0.9248 - val_sparse_categorical_accuracy: 0.5657
# Epoch 44/50
# 44/44 [==============================] - 23s 527ms/step - loss: 0.9223 - sparse_categorical_accuracy: 0.5610 - val_loss: 0.9247 - val_sparse_categorical_accuracy: 0.5673
# Epoch 45/50
# 44/44 [==============================] - 23s 521ms/step - loss: 0.9187 - sparse_categorical_accuracy: 0.5679 - val_loss: 0.9237 - val_sparse_categorical_accuracy: 0.5706
# Epoch 46/50
# 44/44 [==============================] - 23s 521ms/step - loss: 0.9188 - sparse_categorical_accuracy: 0.5708 - val_loss: 0.9228 - val_sparse_categorical_accuracy: 0.5698
# Epoch 47/50
# 44/44 [==============================] - 23s 525ms/step - loss: 0.9213 - sparse_categorical_accuracy: 0.5677 - val_loss: 0.9234 - val_sparse_categorical_accuracy: 0.5633
# Epoch 48/50
# 44/44 [==============================] - 23s 525ms/step - loss: 0.9204 - sparse_categorical_accuracy: 0.5681 - val_loss: 0.9221 - val_sparse_categorical_accuracy: 0.5706
# Epoch 49/50
# 44/44 [==============================] - 23s 523ms/step - loss: 0.9187 - sparse_categorical_accuracy: 0.5641 - val_loss: 0.9216 - val_sparse_categorical_accuracy: 0.5706
# Epoch 50/50
# 44/44 [==============================] - 24s 547ms/step - loss: 0.9189 - sparse_categorical_accuracy: 0.5623 - val_loss: 0.9215 - val_sparse_categorical_accuracy: 0.5755

# %% [markdown]
# ---------------------------------------------------------------------------------------------Evaluate_model-------------------------------------------------------------------------------------------------------------

# %%
Evaluate_models(df_test_freeze,model_freeze,'General_comment',mode[2])
# Out:
# :::::::::::::::Performance of ParsBERT'freeze' on 'General_comment' Label:::::::::::::::::::
#               precision    recall  f1-score   support
#
#            0       0.58      0.35      0.44       269
#            1       0.57      0.86      0.69       575
#            2       0.56      0.30      0.39       381
#
#     accuracy                           0.57      1225
#    macro avg       0.57      0.50      0.50      1225
# weighted avg       0.57      0.57      0.54      1225
#
# Accuracy: 0.572245
#
# Precision:0.569902
#
# Recall: 0.502311
#
# F1 score: 0.50488
#
#
#
#
#
#
# -----------------------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------------------
#                                             Record_text  InRelationship  \
# 0     حالا در مورد زید یه خاکی بریز شوهر شد دوبار خا...              -1
# 1     : دوست پسر من باید مثل خودم کاسب باشه یعنی چی ...               1
# 2     : ولی نمیشه خانوم ها  تا شوهر کنن چهار به یک چ...              -1
# 3     من یکی از فانتزی هام اینکه اگه ازدواج کردم همس...               0
# 4     یه بحران دیگه داریم که به نظر بحران اصلی اونه:...               0
# ...                                                 ...             ...
# 1220  از اونجایی که همه چیز دو طرفست، وقتی راضی نیست...               1
# 1221  خفه شو بابا برو زنتو جمع کن از دست فرانسوی ها ...              -1
# 1222  خیانت ربطی به زیبایی پارتنر طرف نداره بلکه به ...              -1
# 1223  به زنم این دریافتم را گفتم. اون هم خوب که درمو...               1
# 1224  مرده رفته دادگاه گفته که نمیخوام زنم شهر دیگه ...              -1
#
#       General_comment_binary  label  Specific_comment_binary  \
# 0                          1      1                      0.0
# 1                          1      1                      1.0
# 2                          1      0                      0.0
# 3                          1      0                      0.0
# 4                          1      1                      0.0
# ...                      ...    ...                      ...
# 1220                       1      2                      1.0
# 1221                       1      1                      0.0
# 1222                       1      1                      0.0
# 1223                       1      2                      1.0
# 1224                       1      1                      0.0
#
#       Specific_comment                                            Comment  \
# 0                    3     احتمالا زید یه جیزی بوده که نوشته یه خاکی بریز
# 1                    1  دوست پسرش بهش پیام داده بریم بیرون اما این خوش...
# 2                    3  اینکه خانما الان یدونه شوهر میتونن داشته باشن،...
# 3                    3  این تبارها از نظر این شخص گزینه خوبی برای ازدو...
# 4                    3                                حرف ازدواج اصلا نزن
# ...                ...                                                ...
# 1220                 2                                              کامنت
# 1221                 3                                              کامنت
# 1222                 3                                              کامنت
# 1223                 2                                              کامنت
# 1224                 3                                              کامنت
#
#       Relevance  pred_label
# 0             1           1
# 1             1           1
# 2             1           1
# 3             1           0
# 4             1           1
# ...         ...         ...
# 1220          1           1
# 1221          1           1
# 1222          1           1
# 1223          1           1
# 1224          1           1
#
# [1225 rows x 9 columns]
